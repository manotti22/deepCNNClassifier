# %%
import os
os.chdir('C:\\Users\\HPr\\Desktop\\Projekte\\deepCNNClassifier')

# %%
os.getcwd()
# Out:
# 'c:\\Users\\HPr\\Desktop\\Projekte\\deepCNNClassifier\\research'

# %%
import tensorflow as tf

# %%
model = tf.keras.models.load_model("./artifacts/training/model.h5")

# %%
from PIL import Image

img = Image.open("./artifacts/data_ingestion/PetImages/Cat/0.jpg")
img = img.resize((224,224))

# %%
import numpy as np
img_array = np.array(img)

# %%
img_array.shape
# Out:
# (224, 224, 3)

# %%
img_array = np.expand_dims(img_array, axis=0)
img_array.shape
# Out:
# (1, 224, 224, 3)

# %%
result = model.predict(img_array)
result
# Out:
# 1/1 [==============================] - 1s 886ms/step
# array([[1., 0.]], dtype=float32)

# %%
argmax_index = np.argmax(result, axis=1)
if argmax_index[0] == 0:
    print("predicted: cat")
else:
    print("predicted: dog")
# Out:
# predicted: cat
